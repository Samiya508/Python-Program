# %%
#1 palindrom
str=input("Enter String")
str1=str[::-1]
if str==str1:
    print("palindrom")
else:
    print("not palindrom")
# Out:
# Enter String samas
# palindrom

# %%
#2calculate the gcd using loops and if - else statements 

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
gcd = 1
for i in range(1, min(num1, num2) + 1): 
    if num1 % i == 0 and num2 % i == 0:
        gcd = i
print("GCD:", gcd)
# Out:
# Enter first number:  10
# Enter second number:  20
# GCD: 10

# %%
#3. Take a string and count the number of words.
str1 = input("Enter a string: ")
words = str1.split()
count = len(words)
print("Number of words in the string is:", count)
# Out:
# Enter a string:  samiya
# Number of words in the string is: 1

# %%
#4. print the following patterns for N=5.
for i in range(1, 6):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
#5. reverse a given integer without converting it to a string.
num = eval(input("enter a number: "))
reverse = 0 
while num> 0:
    digit = num % 10 
    reverse = reverse * 10 + digit
    num //= 10
print("Reverse of the number is:", reverse)
# Out:
# enter a number:  56
# Reverse of the number is: 65

# %%
#6Take N numbers as input and print the sum of their squares.

n = int(input("Enter the number of values: "))  
sum_of_squares = 0
for _ in range(n):
    value = int(input("Enter a number: "))
    sum_of_squares += value ** 2
print("Sum of squares:", sum_of_squares)
# Out:
# Enter the number of values:  2
# Enter a number:  2
# Enter a number:  2
# Sum of squares: 8

# %%
#7Check whether a number is an Armstrong number.

num = eval(input("Enter a number: "))
cube = 0  
temp = num
while temp > 0:
    digit = temp % 10 
    cube += digit ** 3
    temp //= 10
if num == cube:
    print(num, "is an Armstrong number.")
else:
    print(num, "is not an Armstrong number.")
# Out:
# Enter a number:  10
# 10 is not an Armstrong number.

# %%
 #8 count the frequency of each character in a string
string = input("Enter a string: ")
frequency = {}
for char in string:
     frequency[char] = frequency.get(char, 0) + 1
     print("Character frequencies:", frequency)
frequency = {}
# Out:
# Enter a string:  samiya
# Character frequencies: {'s': 1}
# Character frequencies: {'s': 1, 'a': 1}
# Character frequencies: {'s': 1, 'a': 1, 'm': 1}
# Character frequencies: {'s': 1, 'a': 1, 'm': 1, 'i': 1}
# Character frequencies: {'s': 1, 'a': 1, 'm': 1, 'i': 1, 'y': 1}
# Character frequencies: {'s': 1, 'a': 2, 'm': 1, 'i': 1, 'y': 1}

# %%
# 9.Print all odd numbers from 50 down to 1 using a loop.

for i in range (49,0,-2):
    print(i)
# Out:
# 49
# 47
# 45
# 43
# 41
# 39
# 37
# 35
# 33
# 31
# 29
# 27
# 25
# 23
# 21
# 19
# 17
# 15
# 13
# 11
# 9
# 7
# 5
# 3
# 1

# %%
#10Build a basic calculator that takes two numbers and an operator and performs the operation

a=int(input(print("enter 1 st no :")))
b=int(input(print(" 1-> +  2-> - 3-> *  4->/ :")))
c=int(input(print("enter 2 st no :")))

if b==1:
    d=a+c
    print(d)
elif b==2:
    d=a-c
    print(d)
elif b==3:
    d=a*c
    print(d)
elif b==4:
    d=a/c
    print(d)
else :
    print("error")
# Out:
# enter 1 st no :
# None 1
#  1-> +  2-> - 3-> *  4->/ :
# None 2
# enter 2 st no :
# None 3
# -2
